# %%
import os
import re
import csv
import copy
import pickle
import pandas as pd
from itertools import combinations

# %%
entities = ['action', 'label', 'data']

# %%
label_syn = [("username", "user name"), ("next", "previous"), ("complete", "ok"), ("user id", "userid")]

# %%
action_syn = [("select", "click", "deselect"), ("verify", "validate"), ("clicking", "selecting"), 
              ("navigate", "go to", "on"), ("login", "log in", "enter"), ("logout", "log out")]

# %%
action_dict = {}

for item in action_syn:
    pairs = list(combinations(item, 2))
    for x, y in pairs:
        action_dict.setdefault(x, []).append(y)
        action_dict.setdefault(y, []).append(x)

# %%
action_dict
# Out:
# {'select': ['click', 'deselect'],
#  'click': ['select', 'deselect'],
#  'deselect': ['select', 'click'],
#  'verify': ['validate'],
#  'validate': ['verify'],
#  'clicking': ['selecting'],
#  'selecting': ['clicking'],
#  'navigate': ['go to', 'on'],
#  'go to': ['navigate', 'on'],
#  'on': ['navigate', 'go to'],
#  'login': ['log in', 'enter'],
#  'log in': ['login', 'enter'],
#  'enter': ['login', 'log in'],
#  'logout': ['log out'],
#  'log out': ['logout']}

# %%
label_dict = {}

for item in label_syn:
    pairs = list(combinations(item, 2))
    for x, y in pairs:
        label_dict.setdefault(x, []).append(y)
        label_dict.setdefault(y, []).append(x)

# %%
label_dict
# Out:
# {'username': ['user name'],
#  'user name': ['username'],
#  'next': ['previous'],
#  'previous': ['next'],
#  'complete': ['ok'],
#  'ok': ['complete'],
#  'user id': ['userid'],
#  'userid': ['user id']}

# %%
with open("data.pkl", "rb") as pkl_file:
    data_list = pickle.load(pkl_file)

# %%
data_list[:2]
# Out:
# [['Select Asset Class as "CC" and select Deal Type as "TRADE CC" ',
#   ('select', 'Asset Class', 'CC'),
#   ('select', 'Deal Type', 'TRADE CC')],
#  ['Select the following for the Equipment Information section:\na. - Site\nb. - Legal Product Category',
#   ('select', 'site', ''),
#   ('select', 'Legal Product Category', '')]]

# %%
preprocess_list = []

def clean_data(text):
    text = re.sub('([!?,\'".\n\-\:\*\/])', r' \1 ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()

def preprocess_data(data_list):
    for item in data_list:
        text, triplets = item[0], item[1:] 
        text = clean_data(text)
        tmp_list = [text]
        for action, label, data in triplets:
            if action: action = clean_data(action)
            if label: label = clean_data(label)
            if data: data = clean_data(data)
            tmp_list.append((action, label, data))
        preprocess_list.append(tmp_list)   
        
preprocess_data(data_list)

# %%
text = """Select Asset Class as "CC" and: select Deal Type as "TRADE CC" test122 """

clean_data(text)
# Out:
# 'Select Asset Class as " CC " and : select Deal Type as " TRADE CC " test122'

# %%
augmented_list = []

def augment_data(data_list):
    for item in data_list:
        text, triplets = item[0], item[1:]
        augmented_list.append(item)
        unique_actions, unique_labels = set(), set()
        
        for action, label, data in triplets:
            if action: unique_actions.add(action.lower())
            if label: unique_labels.add(label.lower())
        
        for action in unique_actions:
            for similar_action in action_dict.get(action, []):
                new_item = copy.deepcopy(item)
                new_text, new_triplets = new_item[0].lower(), new_item[1:]
                if action in new_text: 
                    new_text = new_text.replace(action, similar_action)
                    new_triplets = [(similar_action, y, z) if x.lower() == action else (x,y,z) for (x,y,z) in new_triplets]
                    augmented_list.append([new_text, *new_triplets])
                    
        for label in unique_labels:
            for similar_label in label_dict.get(label, []):
                new_item = copy.deepcopy(item)
                new_text, new_triplets = new_item[0].lower(), new_item[1:]
                if label in new_text: 
                    new_text = new_text.replace(label, similar_label)
                    new_triplets = [(x, similar_label, z) if y.lower() == label else (x,y,z) for (x,y,z) in new_triplets]
                    augmented_list.append([new_text, *new_triplets])
        
augment_data(preprocess_list)

# %%
from pprint import pprint
len(augmented_list)
# Out:
# 434

# %%
augmented_list
# Out:
# [['Select Asset Class as " CC " and select Deal Type as " TRADE CC "',
#   ('select', 'Asset Class', 'CC'),
#   ('select', 'Deal Type', 'TRADE CC')],
#  ['click asset class as " cc " and click deal type as " trade cc "',
#   ('click', 'Asset Class', 'CC'),
#   ('click', 'Deal Type', 'TRADE CC')],
#  ['deselect asset class as " cc " and deselect deal type as " trade cc "',
#   ('deselect', 'Asset Class', 'CC'),
#   ('deselect', 'Deal Type', 'TRADE CC')],
#  ['Select the following for the Equipment Information section : \n a . - Site \n b . - Legal Product Category',
#   ('select', 'site', ''),
#   ('select', 'Legal Product Category', '')],
#  ['click the following for the equipment information section : \n a . - site \n b . - legal product category',
#   ('click', 'site', ''),
#   ('click', 'Legal Product Category', '')],
#  ['deselect the following for the equipment information section : \n a . - site \n b . - legal product category',
#   ('deselect', 'site', ''),
#   ('deselect', 'Legal Product Category', '')],
#  ["Go to ' Action ' dropdown and select ' Pay in Full '",
#   ('select', 'action', 'Pay in Full')],
#  ["go to ' action ' dropdown and click ' pay in full '",
#   ('click', 'action', 'Pay in Full')],
#  ["go to ' action ' dropdown and deselect ' pay in full '",
#   ('deselect', 'action', 'Pay in Full')],
#  ["Click ' Actions ' dropdown and select ' Post to Ledger '",
#   ('select', 'action', 'Post to Ledger')],
#  ["click ' actions ' dropdown and click ' post to ledger '",
#   ('click', 'action', 'Post to Ledger')],
#  ["click ' actions ' dropdown and deselect ' post to ledger '",
#   ('deselect', 'action', 'Post to Ledger')],
#  ['Select branch name as " Retail Branch " , Rep Name as " Retail . io " and click on login',
#   ('select', 'branch name', 'Retail Branch'),
#   ('select', 'Rep Name', 'Retail . io'),
#   ('click', 'login', '')],
#  ['click branch name as " retail branch " , rep name as " retail . io " and click on login',
#   ('click', 'branch name', 'Retail Branch'),
#   ('click', 'Rep Name', 'Retail . io'),
#   ('click', 'login', '')],
#  ['deselect branch name as " retail branch " , rep name as " retail . io " and click on login',
#   ('deselect', 'branch name', 'Retail Branch'),
#   ('deselect', 'Rep Name', 'Retail . io'),
#   ('click', 'login', '')],
#  ['select branch name as " retail branch " , rep name as " retail . io " and select on login',
#   ('select', 'branch name', 'Retail Branch'),
#   ('select', 'Rep Name', 'Retail . io'),
#   ('select', 'login', '')],
#  ['select branch name as " retail branch " , rep name as " retail . io " and deselect on login',
#   ('select', 'branch name', 'Retail Branch'),
#   ('select', 'Rep Name', 'Retail . io'),
#   ('deselect', 'login', '')],
#  ['Select the reason : Cancel Invoice',
#   ('select', 'reason', 'cancel invoice')],
#  ['click the reason : cancel invoice', ('click', 'reason', 'cancel invoice')],
#  ['deselect the reason : cancel invoice',
#   ('deselect', 'reason', 'cancel invoice')],
#  ['Assign voice lines to the user and Enter " test1222 " in username input',
#   ('assign', 'user', 'voice lines'),
#   ('enter', 'username', 'test1222')],
#  ['assign voice lines to the user and login " test1222 " in username input',
#   ('assign', 'user', 'voice lines'),
#   ('login', 'username', 'test1222')],
#  ['assign voice lines to the user and log in " test1222 " in username input',
#   ('assign', 'user', 'voice lines'),
#   ('log in', 'username', 'test1222')],
#  ['assign voice lines to the user and enter " test1222 " in user name input',
#   ('assign', 'user', 'voice lines'),
#   ('enter', 'user name', 'test1222')],
#  ['On select user , selected data should be showed', ('select', '', 'user')],
#  ['on click user , clicked data should be showed', ('click', '', 'user')],
#  ['on deselect user , deselected data should be showed',
#   ('deselect', '', 'user')],
#  ['Verify country dropdown is on the page and select india after opening the dropdown',
#   ('verify', 'country', ''),
#   ('select', '', 'india')],
#  ['verify country dropdown is on the page and click india after opening the dropdown',
#   ('verify', 'country', ''),
#   ('click', '', 'india')],
#  ['verify country dropdown is on the page and deselect india after opening the dropdown',
#   ('verify', 'country', ''),
#   ('deselect', '', 'india')],
#  ['validate country dropdown is on the page and select india after opening the dropdown',
#   ('validate', 'country', ''),
#   ('select', '', 'india')],
#  ['Enter " test1222 " in username input', ('enter', 'username', 'test1222')],
#  ['login " test1222 " in username input', ('login', 'username', 'test1222')],
#  ['log in " test1222 " in username input', ('log in', 'username', 'test1222')],
#  ['enter " test1222 " in user name input', ('enter', 'user name', 'test1222')],
#  ['Enter the following information to login 1) username 2) password',
#   ('enter', 'username', ''),
#   ('enter', 'password', '')],
#  ['login the following information to login 1) username 2) password',
#   ('login', 'username', ''),
#   ('login', 'password', '')],
#  ['log in the following information to login 1) username 2) password',
#   ('log in', 'username', ''),
#   ('log in', 'password', '')],
#  ['enter the following information to login 1) user name 2) password',
#   ('enter', 'user name', ''),
#   ('enter', 'password', '')],
#  ['To create lead , enter username , lead name and address',
#   ('enter', 'username', ''),
#   ('enter', 'lead name', ''),
#   ('enter', 'address', '')],
#  ['to create lead , login username , lead name and address',
#   ('login', 'username', ''),
#   ('login', 'lead name', ''),
#   ('login', 'address', '')],
#  ['to create lead , log in username , lead name and address',
#   ('log in', 'username', ''),
#   ('log in', 'lead name', ''),
#   ('log in', 'address', '')],
#  ['to create lead , enter user name , lead name and address',
#   ('enter', 'user name', ''),
#   ('enter', 'lead name', ''),
#   ('enter', 'address', '')],
#  ['Enter " basket " in " field " data and enter " milk " in " search "',
#   ('Enter', 'field', 'basket'),
#   ('enter', 'search', 'milk')],
#  ['login " basket " in " field " data and login " milk " in " search "',
#   ('login', 'field', 'basket'),
#   ('login', 'search', 'milk')],
#  ['log in " basket " in " field " data and log in " milk " in " search "',
#   ('log in', 'field', 'basket'),
#   ('log in', 'search', 'milk')],
#  ['Click on login button', ('click', 'login', '')],
#  ['select on login button', ('select', 'login', '')],
#  ['deselect on login button', ('deselect', 'login', '')],
#  ['Save the lead by clicking on save', ('clicking', 'save', '')],
#  ['save the lead by selecting on save', ('selecting', 'save', '')],
#  ['Verify Manage Payments page is displays',
#   ('verify', 'manage payments page', '')],
#  ['validate manage payments page is displays',
#   ('validate', 'manage payments page', '')],
#  ['Verify Invoice Line gets displayed', ('verify', 'invoice line', '')],
#  ['validate invoice line gets displayed', ('validate', 'invoice line', '')],
#  ['Verify " test " is on the screen', ('verify', 'test', '')],
#  ['validate " test " is on the screen', ('validate', 'test', '')],
#  ['On clicking on edit , verify edit page is displayed',
#   ('clicking', 'edit', ''),
#   ('verify', 'edit page', '')],
#  ['on clicking on edit , validate edit page is displayed',
#   ('clicking', 'edit', ''),
#   ('validate', 'edit page', '')],
#  ['on selecting on edit , verify edit page is displayed',
#   ('selecting', 'edit', ''),
#   ('verify', 'edit page', '')],
#  ['Verify FICO Details are reflecting in Borrower details Tab',
#   ('verify', 'Fico Details', '')],
#  ['validate fico details are reflecting in borrower details tab',
#   ('validate', 'Fico Details', '')],
#  ['Click Trades tab from the list of tabs in XVA Home page',
#   ('click', 'trades tab', '')],
#  ['select trades tab from the list of tabs in xva home page',
#   ('select', 'trades tab', '')],
#  ['deselect trades tab from the list of tabs in xva home page',
#   ('deselect', 'trades tab', '')],
#  ['Navigate to Manage Users Page by clicking on the Users link',
#   ('clicking', 'users', '')],
#  ['navigate to manage users page by selecting on the users link',
#   ('selecting', 'users', '')],
#  ['Navigate to url https : / / www . spectrumbusiness . net / # / login',
#   ('navigate', 'url', '')],
#  ['go to to url https : / / www . spectrumbusiness . net / # / login',
#   ('go to', 'url', '')],
#  ['on to url https : / / www . spectrumbusiness . net / # / login',
#   ('on', 'url', '')],
#  ['Enter the Account Owner username and password and click on Sign In',
#   ('enter', 'username', ''),
#   ('enter', 'password', ''),
#   ('click', 'sign in', '')],
#  ['login the account owner username and password and click on sign in',
#   ('login', 'username', ''),
#   ('login', 'password', ''),
#   ('click', 'sign in', '')],
#  ['log in the account owner username and password and click on sign in',
#   ('log in', 'username', ''),
#   ('log in', 'password', ''),
#   ('click', 'sign in', '')],
#  ['enter the account owner username and password and select on sign in',
#   ('enter', 'username', ''),
#   ('enter', 'password', ''),
#   ('select', 'sign in', '')],
#  ['enter the account owner username and password and deselect on sign in',
#   ('enter', 'username', ''),
#   ('enter', 'password', ''),
#   ('deselect', 'sign in', '')],
#  ['enter the account owner user name and password and click on sign in',
#   ('enter', 'user name', ''),
#   ('enter', 'password', ''),
#   ('click', 'sign in', '')],
#  ['Navigate to Manage Users Page [Overview - >Manage Users] and click on Add User button',
#   ('navigate', 'Overview', ''),
#   ('navigate', 'Manage Users', ''),
#   ('click', 'Add User', '')],
#  ['navigate to manage users page [overview - >manage users] and select on add user button',
#   ('navigate', 'Overview', ''),
#   ('navigate', 'Manage Users', ''),
#   ('select', 'Add User', '')],
#  ['navigate to manage users page [overview - >manage users] and deselect on add user button',
#   ('navigate', 'Overview', ''),
#   ('navigate', 'Manage Users', ''),
#   ('deselect', 'Add User', '')],
#  ['go to to manage users page [overview - >manage users] and click on add user button',
#   ('go to', 'Overview', ''),
#   ('go to', 'Manage Users', ''),
#   ('click', 'Add User', '')],
#  ['on to manage users page [overview - >manage users] and click on add user button',
#   ('on', 'Overview', ''),
#   ('on', 'Manage Users', ''),
#   ('click', 'Add User', '')],
#  ['Complete the Add New Standard User steps without assigning a line to the Standard User',
#   ('complete', 'Add New Standard User', '')],
#  ['Logout of SpectrumBusiness . Net Account Owner User',
#   ('logout', 'account owner', '')],
#  ['log out of spectrumbusiness . net account owner user',
#   ('log out', 'account owner', '')],
#  ['Login into the registered email address given during standard user creation and Activate the standard User',
#   ('login', 'registered email address', ''),
#   ('activate', 'standard user', '')],
#  ['log in into the registered email address given during standard user creation and activate the standard user',
#   ('log in', 'registered email address', ''),
#   ('activate', 'standard user', '')],
#  ['enter into the registered email address given during standard user creation and activate the standard user',
#   ('enter', 'registered email address', ''),
#   ('activate', 'standard user', '')],
#  ['On the account Summary page , verify that the Voice Tile is not displayed',
#   ('on', 'account summary', ''),
#   ('verify', 'voice tile', '')],
#  ['navigate the account summary page , verify that the voice tile is not displayed',
#   ('navigate', 'account summary', ''),
#   ('verify', 'voice tile', '')],
#  ['go to the account summary page , verify that the voice tile is not displayed',
#   ('go to', 'account summary', ''),
#   ('verify', 'voice tile', '')],
#  ['on the account summary page , validate that the voice tile is not displayed',
#   ('on', 'account summary', ''),
#   ('validate', 'voice tile', '')],
#  ['Log out of Spectrum Business . Net Standard user',
#   ('Log out', 'Standard user', '')],
#  ['logout of spectrum business . net standard user',
#   ('logout', 'Standard user', '')],
#  ['Login into SpectrumBusiness . Net using the Account holder User',
#   ('Login', 'Account holder User', '')],
#  ['log in into spectrumbusiness . net using the account holder user',
#   ('log in', 'Account holder User', '')],
#  ['enter into spectrumbusiness . net using the account holder user',
#   ('enter', 'Account holder User', '')],
#  ['Navigate to Manage lines in Voice tile',
#   ('navigate', 'voice tile', ''),
#   ('navigate', 'manage lines', '')],
#  ['go to to manage lines in voice tile',
#   ('go to', 'voice tile', ''),
#   ('go to', 'manage lines', '')],
#  ['on to manage lines in voice tile',
#   ('on', 'voice tile', ''),
#   ('on', 'manage lines', '')],
#  ['Click on a voice line and click on Edit and assign a Voice line to the Standard user and save the changes',
#   ('click', 'voice line', ''),
#   ('click', 'edit', ''),
#   ('assign', 'voice line', ''),
#   ('save', '', '')],
#  ['select on a voice line and select on edit and assign a voice line to the standard user and save the changes',
#   ('select', 'voice line', ''),
#   ('select', 'edit', ''),
#   ('assign', 'voice line', ''),
#   ('save', '', '')],
#  ['deselect on a voice line and deselect on edit and assign a voice line to the standard user and save the changes',
#   ('deselect', 'voice line', ''),
#   ('deselect', 'edit', ''),
#   ('assign', 'voice line', ''),
#   ('save', '', '')],
#  ['Logout of SpectrumBusiness . Net Account Owner User',
#   ('logout', 'account owner user', '')],
#  ['log out of spectrumbusiness . net account owner user',
#   ('log out', 'account owner user', '')],
#  ['Login into SpectrumBusiness . Net using the Standard User',
#   ('login', 'standard user', '')],
#  ['log in into spectrumbusiness . net using the standard user',
#   ('log in', 'standard user', '')],
#  ['enter into spectrumbusiness . net using the standard user',
#   ('enter', 'standard user', '')],
#  ['Click on the Voice Tile and verify whether user is redirected to the Voice Messages page of the newly assigned phone line .',
#   ('click', 'voice tile', ''),
#   ('verify', 'Voice Messages', '')],
#  ['click on the voice tile and validate whether user is redirected to the voice messages page of the newly assigned phone line .',
#   ('click', 'voice tile', ''),
#   ('validate', 'Voice Messages', '')],
#  ['select on the voice tile and verify whether user is redirected to the voice messages page of the newly assigned phone line .',
#   ('select', 'voice tile', ''),
#   ('verify', 'Voice Messages', '')],
#  ['deselect on the voice tile and verify whether user is redirected to the voice messages page of the newly assigned phone line .',
#   ('deselect', 'voice tile', ''),
#   ('verify', 'Voice Messages', '')],
#  ['Navigate to Manage User Page by clicking on the Users link',
#   ('navigate', 'manage user', ''),
#   ('clicking', 'User', '')],
#  ['navigate to manage user page by selecting on the users link',
#   ('navigate', 'manage user', ''),
#   ('selecting', 'User', '')],
#  ['go to to manage user page by clicking on the users link',
#   ('go to', 'manage user', ''),
#   ('clicking', 'User', '')],
#  ['on to manage user page by clicking on the users link',
#   ('on', 'manage user', ''),
#   ('clicking', 'User', '')],
#  ['Click on the Standard user from the user list',
#   ('click', 'user list', 'standard user')],
#  ['select on the standard user from the user list',
#   ('select', 'user list', 'standard user')],
#  ['deselect on the standard user from the user list',
#   ('deselect', 'user list', 'standard user')],
#  ["Click on ' Edit ' link on the user detail page",
#   ('click', 'user detail', 'edit')],
#  ["select on ' edit ' link on the user detail page",
#   ('select', 'user detail', 'edit')],
#  ["deselect on ' edit ' link on the user detail page",
#   ('deselect', 'user detail', 'edit')],
#  ["Click on ' Delete User ' link on the Edit user page",
#   ('click', 'edit user', 'delete user')],
#  ["select on ' delete user ' link on the edit user page",
#   ('select', 'edit user', 'delete user')],
#  ["deselect on ' delete user ' link on the edit user page",
#   ('deselect', 'edit user', 'delete user')],
#  ["Click on ' Confirm ' button on the ' Delete User ' popup",
#   ('click', 'delete user', 'confirm')],
#  ["select on ' confirm ' button on the ' delete user ' popup",
#   ('select', 'delete user', 'confirm')],
#  ["deselect on ' confirm ' button on the ' delete user ' popup",
#   ('deselect', 'delete user', 'confirm')],
#  ['Login to " H20 " Application with valid user name and password',
#   ('login', 'user name', ''),
#   ('login', 'password', '')],
#  ['log in to " h20 " application with valid user name and password',
#   ('log in', 'user name', ''),
#   ('log in', 'password', '')],
#  ['enter to " h20 " application with valid user name and password',
#   ('enter', 'user name', ''),
#   ('enter', 'password', '')],
#  ['login to " h20 " application with valid username and password',
#   ('login', 'username', ''),
#   ('login', 'password', '')],
#  ['Mouse hover to " Loan " tab and click on " Create New Loan " Button',
#   ('mouse hover', 'loan', ''),
#   ('click', 'create new loan', '')],
#  ['mouse hover to " loan " tab and select on " create new loan " button',
#   ('mouse hover', 'loan', ''),
#   ('select', 'create new loan', '')],
#  ['mouse hover to " loan " tab and deselect on " create new loan " button',
#   ('mouse hover', 'loan', ''),
#   ('deselect', 'create new loan', '')],
#  ['Select branch name as " Retail Branch " , Rep Name as " Retail . io "',
#   ('select', 'branch name', 'retail branch'),
#   ('select', 'rep name', 'retail . io')],
#  ['click branch name as " retail branch " , rep name as " retail . io "',
#   ('click', 'branch name', 'retail branch'),
#   ('click', 'rep name', 'retail . io')],
#  ['deselect branch name as " retail branch " , rep name as " retail . io "',
#   ('deselect', 'branch name', 'retail branch'),
#   ('deselect', 'rep name', 'retail . io')],
#  ['Select Lead Type 1 as " Self Generated " and Lead source 1 as " Purchase "',
#   ('select', 'lead type 1', 'self generated'),
#   ('select', 'source 1', 'purchase')],
#  ['click lead type 1 as " self generated " and lead source 1 as " purchase "',
#   ('click', 'lead type 1', 'self generated'),
#   ('click', 'source 1', 'purchase')],
#  ['deselect lead type 1 as " self generated " and lead source 1 as " purchase "',
#   ('deselect', 'lead type 1', 'self generated'),
#   ('deselect', 'source 1', 'purchase')],
#  ['Click on " Create Loan By " dropdown and select " Copy From Existing " Loan',
#   ('click', 'create loan by', ''),
#   ('select', 'copy from existing', '')],
#  ['click on " create loan by " dropdown and click " copy from existing " loan',
#   ('click', 'create loan by', ''),
#   ('click', 'copy from existing', '')],
#  ['click on " create loan by " dropdown and deselect " copy from existing " loan',
#   ('click', 'create loan by', ''),
#   ('deselect', 'copy from existing', '')],
#  ['select on " create loan by " dropdown and select " copy from existing " loan',
#   ('select', 'create loan by', ''),
#   ('select', 'copy from existing', '')],
#  ['deselect on " create loan by " dropdown and select " copy from existing " loan',
#   ('deselect', 'create loan by', ''),
#   ('select', 'copy from existing', '')],
#  ['Click on " Matches " and Select any loan number to copy',
#   ('click', 'matches', ''),
#   ('select', 'loan number', '')],
#  ['click on " matches " and click any loan number to copy',
#   ('click', 'matches', ''),
#   ('click', 'loan number', '')],
#  ['click on " matches " and deselect any loan number to copy',
#   ('click', 'matches', ''),
#   ('deselect', 'loan number', '')],
#  ['select on " matches " and select any loan number to copy',
#   ('select', 'matches', ''),
#   ('select', 'loan number', '')],
#  ['deselect on " matches " and select any loan number to copy',
#   ('deselect', 'matches', ''),
#   ('select', 'loan number', '')],
#  ['Click on " Search " button', ('click', 'search', '')],
#  ['select on " search " button', ('select', 'search', '')],
#  ['deselect on " search " button', ('deselect', 'search', '')],
#  ['Click on " Copy "', ('click', 'copy', '')],
#  ['select on " copy "', ('select', 'copy', '')],
#  ['deselect on " copy "', ('deselect', 'copy', '')],
#  ['Select state from " Subject Property state " dropdown .',
#   ('select', 'Subject Property state', '')],
#  ['click state from " subject property state " dropdown .',
#   ('click', 'Subject Property state', '')],
#  ['deselect state from " subject property state " dropdown .',
#   ('deselect', 'Subject Property state', '')],
#  ['Click on " Next " Button', ('click', 'next', '')],
#  ['select on " next " button', ('select', 'next', '')],
#  ['deselect on " next " button', ('deselect', 'next', '')],
#  ['click on " previous " button', ('click', 'previous', '')],
#  ['Click on " Create Loan By " dropdown and select " Import DU 3 . 2 FILE " .',
#   ('click', 'create loan by', ''),
#   ('select', 'import DU 3 . 2 file', '')],
#  ['click on " create loan by " dropdown and click " import du 3 . 2 file " .',
#   ('click', 'create loan by', ''),
#   ('click', 'import DU 3 . 2 file', '')],
#  ['click on " create loan by " dropdown and deselect " import du 3 . 2 file " .',
#   ('click', 'create loan by', ''),
#   ('deselect', 'import DU 3 . 2 file', '')],
#  ['select on " create loan by " dropdown and select " import du 3 . 2 file " .',
#   ('select', 'create loan by', ''),
#   ('select', 'import DU 3 . 2 file', '')],
#  ['deselect on " create loan by " dropdown and select " import du 3 . 2 file " .',
#   ('deselect', 'create loan by', ''),
#   ('select', 'import DU 3 . 2 file', '')],
#  ['Click on Browse and Select document',
#   ('click', 'browse', ''),
#   ('select', 'document', '')],
#  ['click on browse and click document',
#   ('click', 'browse', ''),
#   ('click', 'document', '')],
#  ['click on browse and deselect document',
#   ('click', 'browse', ''),
#   ('deselect', 'document', '')],
#  ['select on browse and select document',
#   ('select', 'browse', ''),
#   ('select', 'document', '')],
#  ['deselect on browse and select document',
#   ('deselect', 'browse', ''),
#   ('select', 'document', '')],
#  ['Open Any retail loan', ('open', 'retail loan', '')],
#  ['Click on " Credit " in left " Status " tab',
#   ('click', 'credit', ''),
#   ('click', 'status', '')],
#  ['select on " credit " in left " status " tab',
#   ('select', 'credit', ''),
#   ('select', 'status', '')],
#  ['deselect on " credit " in left " status " tab',
#   ('deselect', 'credit', ''),
#   ('deselect', 'status', '')],
#  ['Select Credit provide from " Credit provider " dropdown',
#   ('select', 'credit provider', ''),
#   ('select', 'credit provide', '')],
#  ['click credit provide from " credit provider " dropdown',
#   ('click', 'credit provider', ''),
#   ('click', 'credit provide', '')],
#  ['deselect credit provide from " credit provider " dropdown',
#   ('deselect', 'credit provider', ''),
#   ('deselect', 'credit provide', '')],
#  ['Select Radio button " Joint " Under Borrower Section .',
#   ('select', 'Borrower section', ''),
#   ('select', 'joint', '')],
#  ['click radio button " joint " under borrower section .',
#   ('click', 'Borrower section', ''),
#   ('click', 'joint', '')],
#  ['deselect radio button " joint " under borrower section .',
#   ('deselect', 'Borrower section', ''),
#   ('deselect', 'joint', '')],
#  ['Check " Borrower acknowledges credit Request " Check box',
#   ('check', 'Borrower acknowledges credit Request', '')],
#  ['Deselect " Auto Copy Liabilities " check box',
#   ('deselect', 'Auto Copy Liabilities', '')],
#  ['select " auto copy liabilities " check box',
#   ('select', 'Auto Copy Liabilities', '')],
#  ['click " auto copy liabilities " check box',
#   ('click', 'Auto Copy Liabilities', '')],
#  ['Click on " Submit " button', ('click', 'submit', '')],
#  ['select on " submit " button', ('select', 'submit', '')],
#  ['deselect on " submit " button', ('deselect', 'submit', '')],
#  ['Click on " OK " in confirmation popup', ('click', 'ok', '')],
#  ['select on " ok " in confirmation popup', ('select', 'ok', '')],
#  ['deselect on " ok " in confirmation popup', ('deselect', 'ok', '')],
#  ['click on " complete " in confirmation popup', ('click', 'complete', '')],
#  ['Click on " Refresh " button Till status in " Transaction History " tab becomes " Complete',
#   ('click', 'refresh', ''),
#   ('status', 'Transaction History', 'complete')],
#  ['select on " refresh " button till status in " transaction history " tab becomes " complete',
#   ('select', 'refresh', ''),
#   ('status', 'Transaction History', 'complete')],
#  ['deselect on " refresh " button till status in " transaction history " tab becomes " complete',
#   ('deselect', 'refresh', ''),
#   ('status', 'Transaction History', 'complete')],
#  ['Click on " Loan Summary " under " 1003 "', ('click', 'loan summary', '')],
#  ['select on " loan summary " under " 1003 "', ('select', 'loan summary', '')],
#  ['deselect on " loan summary " under " 1003 "',
#   ('deselect', 'loan summary', '')],
#  ['Validate FICO Details are reflecting in Borrower details Tab',
#   ('validate', 'Borrower details tab', '')],
#  ['verify fico details are reflecting in borrower details tab',
#   ('verify', 'Borrower details tab', '')],
#  ['Login in Oracle Fusion Finance Instance with Approver Login',
#   ('login', 'Oracle Fusion Finance Instance', '')],
#  ['log in in oracle fusion finance instance with approver log in',
#   ('log in', 'Oracle Fusion Finance Instance', '')],
#  ['enter in oracle fusion finance instance with approver enter',
#   ('enter', 'Oracle Fusion Finance Instance', '')],
#  ['Navigate to General Accounting - > Journals',
#   ('navigate', 'General Accounting', ''),
#   ('navigate', 'journals', '')],
#  ['go to to general accounting - > journals',
#   ('go to', 'General Accounting', ''),
#   ('go to', 'journals', '')],
#  ['on to general accounting - > journals',
#   ('on', 'General Accounting', ''),
#   ('on', 'journals', '')],
#  ['Click on Task icon and click on Manage Journal',
#   ('click', 'task icon', ''),
#   ('click', 'manage journal', '')],
#  ['select on task icon and select on manage journal',
#   ('select', 'task icon', ''),
#   ('select', 'manage journal', '')],
#  ['deselect on task icon and deselect on manage journal',
#   ('deselect', 'task icon', ''),
#   ('deselect', 'manage journal', '')],
#  ['Enter the Reverse Journal created using Switch Dr and CR method',
#   ('enter', 'reverse journal', '')],
#  ['login the reverse journal created using switch dr and cr method',
#   ('login', 'reverse journal', '')],
#  ['log in the reverse journal created using switch dr and cr method',
#   ('log in', 'reverse journal', '')],
#  ['Click on search', ('click', 'search', '')],
#  ['select on search', ('select', 'search', '')],
#  ['deselect on search', ('deselect', 'search', '')],
#  ['Click on Journal batch', ('click', 'journal batch', '')],
#  ['select on journal batch', ('select', 'journal batch', '')],
#  ['deselect on journal batch', ('deselect', 'journal batch', '')],
#  ['Click on Reject', ('click', 'reject', '')],
#  ['select on reject', ('select', 'reject', '')],
#  ['deselect on reject', ('deselect', 'reject', '')],
#  ['Validate the Approval Status', ('validate', 'approval status', '')],
#  ['verify the approval status', ('verify', 'approval status', '')],
#  ['Logout from the System', ('logout', 'system', '')],
#  ['log out from the system', ('log out', 'system', '')],
#  ['Enter the Reverse Journal created using Change sign Method',
#   ('enter', 'Reverse Journal', '')],
#  ['login the reverse journal created using change sign method',
#   ('login', 'Reverse Journal', '')],
#  ['log in the reverse journal created using change sign method',
#   ('log in', 'Reverse Journal', '')],
#  ['Click on Approve', ('click', 'approve', '')],
#  ['select on approve', ('select', 'approve', '')],
#  ['deselect on approve', ('deselect', 'approve', '')],
#  ['Login in Oracle Fusion Finance Instance with General Accounting Responsibility',
#   ('login', 'Oracle Fusion Finance Instance', '')],
#  ['log in in oracle fusion finance instance with general accounting responsibility',
#   ('log in', 'Oracle Fusion Finance Instance', '')],
#  ['enter in oracle fusion finance instance with general accounting responsibility',
#   ('enter', 'Oracle Fusion Finance Instance', '')],
#  ['Click on Post', ('click', 'post', '')],
#  ['select on post', ('select', 'post', '')],
#  ['deselect on post', ('deselect', 'post', '')],
#  ['Validate the Posting Status', ('validate', 'Posting status', '')],
#  ['verify the posting status', ('verify', 'Posting status', '')],
#  ['Enter the Journal', ('enter', 'journal', '')],
#  ['login the journal', ('login', 'journal', '')],
#  ['log in the journal', ('log in', 'journal', '')],
#  ['Click on Journal batch', ('click', 'Journal batch', '')],
#  ['select on journal batch', ('select', 'Journal batch', '')],
#  ['deselect on journal batch', ('deselect', 'Journal batch', '')],
#  ['Enter the below : \n Reversal Period \n Reversal Method',
#   ('enter', 'Reversal Period', ''),
#   ('enter', 'Reversal Method', '')],
#  ['login the below : \n reversal period \n reversal method',
#   ('login', 'Reversal Period', ''),
#   ('login', 'Reversal Method', '')],
#  ['log in the below : \n reversal period \n reversal method',
#   ('log in', 'Reversal Period', ''),
#   ('log in', 'Reversal Method', '')],
#  ['Click on OK', ('click', 'OK', '')],
#  ['select on ok', ('select', 'OK', '')],
#  ['deselect on ok', ('deselect', 'OK', '')],
#  ['click on complete', ('click', 'complete', '')],
#  ['Search for Journal by Entering Batch as Reverses (Original Journal Entry Name)',
#   ('search', 'journal', ''),
#   ('Entering', 'batch', 'reverses')],
#  ['Enter the Journal created in Test case no 1', ('enter', 'journal', '')],
#  ['login the journal created in test case no 1', ('login', 'journal', '')],
#  ['log in the journal created in test case no 1', ('log in', 'journal', '')],
#  ['Click on Task icon and click on Create Journal',
#   ('click', 'task icon', ''),
#   ('click', 'create journal', '')],
#  ['select on task icon and select on create journal',
#   ('select', 'task icon', ''),
#   ('select', 'create journal', '')],
#  ['deselect on task icon and deselect on create journal',
#   ('deselect', 'task icon', ''),
#   ('deselect', 'create journal', '')],
#  ['Under Journal Batch Enter below fields : \n Journal Batch - \n Description - \n Balance - \n Accounting Period -',
#   ('under', 'journal batch', ''),
#   ('enter', 'journal batch', ''),
#   ('enter', 'description', ''),
#   ('enter', 'balance', ''),
#   ('enter', 'accounting period', '')],
#  ['under journal batch login below fields : \n journal batch - \n description - \n balance - \n accounting period -',
#   ('under', 'journal batch', ''),
#   ('login', 'journal batch', ''),
#   ('login', 'description', ''),
#   ('login', 'balance', ''),
#   ('login', 'accounting period', '')],
#  ['under journal batch log in below fields : \n journal batch - \n description - \n balance - \n accounting period -',
#   ('under', 'journal batch', ''),
#   ('log in', 'journal batch', ''),
#   ('log in', 'description', ''),
#   ('log in', 'balance', ''),
#   ('log in', 'accounting period', '')],
#  ['Under Journal Enter the below fields : \n Journal : \n Description : \n Ledger : \n Accounting Date : \n Category : \n Currency : Euro',
#   ('under', 'journal', ''),
#   ('enter', 'journal', ''),
#   ('enter', 'description', ''),
#   ('enter', 'ledger', ''),
#   ('enter', 'accounting date', ''),
#   ('enter', 'category', ''),
#   ('enter', 'currency', '')],
#  ['under journal login the below fields : \n journal : \n description : \n ledger : \n accounting date : \n category : \n currency : euro',
#   ('under', 'journal', ''),
#   ('login', 'journal', ''),
#   ('login', 'description', ''),
#   ('login', 'ledger', ''),
#   ('login', 'accounting date', ''),
#   ('login', 'category', ''),
#   ('login', 'currency', '')],
#  ['under journal log in the below fields : \n journal : \n description : \n ledger : \n accounting date : \n category : \n currency : euro',
#   ('under', 'journal', ''),
#   ('log in', 'journal', ''),
#   ('log in', 'description', ''),
#   ('log in', 'ledger', ''),
#   ('log in', 'accounting date', ''),
#   ('log in', 'category', ''),
#   ('log in', 'currency', '')],
#  ['Under Journal Lines Enter the below field : \n For Line 1 : Search for Account combination and Click OK \n Enter Debit Amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('enter', 'debit amount', '')],
#  ['under journal lines login the below field : \n for line 1 : search for account combination and click ok \n login debit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('login', 'debit amount', '')],
#  ['under journal lines log in the below field : \n for line 1 : search for account combination and click ok \n log in debit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('log in', 'debit amount', '')],
#  ['under journal lines enter the below field : \n for line 1 : search for account combination and select ok \n enter debit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('select', 'ok', ''),
#   ('enter', 'debit amount', '')],
#  ['under journal lines enter the below field : \n for line 1 : search for account combination and deselect ok \n enter debit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('deselect', 'ok', ''),
#   ('enter', 'debit amount', '')],
#  ['under journal lines enter the below field : \n for line 1 : search for account combination and click complete \n enter debit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'complete', ''),
#   ('enter', 'debit amount', '')],
#  ['Under Journal Lines Enter the below field : \n For Line 2 : Search for Account combination and Click OK \n Enter Credit Amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('enter', 'credit amount', '')],
#  ['under journal lines login the below field : \n for line 2 : search for account combination and click ok \n login credit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('login', 'credit amount', '')],
#  ['under journal lines log in the below field : \n for line 2 : search for account combination and click ok \n log in credit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'ok', ''),
#   ('log in', 'credit amount', '')],
#  ['under journal lines enter the below field : \n for line 2 : search for account combination and select ok \n enter credit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('select', 'ok', ''),
#   ('enter', 'credit amount', '')],
#  ['under journal lines enter the below field : \n for line 2 : search for account combination and deselect ok \n enter credit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('deselect', 'ok', ''),
#   ('enter', 'credit amount', '')],
#  ['under journal lines enter the below field : \n for line 2 : search for account combination and click complete \n enter credit amount',
#   ('under', 'journal lines', ''),
#   ('search', 'Account combination', ''),
#   ('click', 'complete', ''),
#   ('enter', 'credit amount', '')],
#  ['Click on Complete', ('click', 'complete', '')],
#  ['select on complete', ('select', 'complete', '')],
#  ['deselect on complete', ('deselect', 'complete', '')],
#  ['click on ok', ('click', 'ok', '')],
#  ['Under Create Invoice Enter the below fields : \n Invoice Number : \n Business Unit - \n Supplier : \n Supplier Site : \n Payment Terms : \n Amount : \n Invoice Type :',
#   ('under', 'create invoice', ''),
#   ('enter', 'invoice number', ''),
#   ('enter', 'business unit', ''),
#   ('enter', 'supplier', ''),
#   ('enter', 'supplier site', ''),
#   ('enter', 'payment terms', ''),
#   ('enter', 'amount', ''),
#   ('enter', 'invoice type', '')],
#  ['under create invoice login the below fields : \n invoice number : \n business unit - \n supplier : \n supplier site : \n payment terms : \n amount : \n invoice type :',
#   ('under', 'create invoice', ''),
#   ('login', 'invoice number', ''),
#   ('login', 'business unit', ''),
#   ('login', 'supplier', ''),
#   ('login', 'supplier site', ''),
#   ('login', 'payment terms', ''),
#   ('login', 'amount', ''),
#   ('login', 'invoice type', '')],
#  ['under create invoice log in the below fields : \n invoice number : \n business unit - \n supplier : \n supplier site : \n payment terms : \n amount : \n invoice type :',
#   ('under', 'create invoice', ''),
#   ('log in', 'invoice number', ''),
#   ('log in', 'business unit', ''),
#   ('log in', 'supplier', ''),
#   ('log in', 'supplier site', ''),
#   ('log in', 'payment terms', ''),
#   ('log in', 'amount', ''),
#   ('log in', 'invoice type', '')],
#  ['Click on Show more adcent to Invoice Header',
#   ('click', 'Show more adcent to Invoice', '')],
#  ['select on show more adcent to invoice header',
#   ('select', 'Show more adcent to Invoice', '')],
#  ['deselect on show more adcent to invoice header',
#   ('deselect', 'Show more adcent to Invoice', '')],
#  ['Disable the checkbox to apply prepayment immediately',
#   ('disable', 'apply prepayment', '')],
#  ['Go to Lines to match the Line Item . \n Enter the Amount in Line 1',
#   ('go to', 'lines', ''),
#   ('enter', 'amount', '')],
#  ['go to lines to match the line item . \n login the amount in line 1',
#   ('go to', 'lines', ''),
#   ('login', 'amount', '')],
#  ['go to lines to match the line item . \n log in the amount in line 1',
#   ('go to', 'lines', ''),
#   ('log in', 'amount', '')],
#  ['navigate lines to match the line item . \n enter the amount in line 1',
#   ('navigate', 'lines', ''),
#   ('enter', 'amount', '')],
#  ['on lines to match the line item . \n enter the amount in line 1',
#   ('on', 'lines', ''),
#   ('enter', 'amount', '')],
#  ['Enter the Account Number in Distribution Combination field',
#   ('enter', 'Account Number', '')],
#  ['login the account number in distribution combination field',
#   ('login', 'Account Number', '')],
#  ['log in the account number in distribution combination field',
#   ('log in', 'Account Number', '')],
#  ['Click on Distributions Tab above to see the Distribution of Amount to allocated Account',
#   ('click', 'Distributions Tab', '')],
#  ['select on distributions tab above to see the distribution of amount to allocated account',
#   ('select', 'Distributions Tab', '')],
#  ['deselect on distributions tab above to see the distribution of amount to allocated account',
#   ('deselect', 'Distributions Tab', '')],
#  ['Click on Save and Close', ('click', 'save', '')],
#  ['select on save and close', ('select', 'save', '')],
#  ['deselect on save and close', ('deselect', 'save', '')],
#  ['Click on Save button to Save the Invoice', ('click', 'save', '')],
#  ['select on save button to save the invoice', ('select', 'save', '')],
#  ['deselect on save button to save the invoice', ('deselect', 'save', '')],
#  ['Validate and make the Payment for the Invoice',
#   ('validate', 'Payment', '')],
#  ['verify and make the payment for the invoice', ('verify', 'Payment', '')],
#  ['Enter the Invoice number and click on Search',
#   ('enter', 'invoice number', ''),
#   ('click', 'search', '')],
#  ['login the invoice number and click on search',
#   ('login', 'invoice number', ''),
#   ('click', 'search', '')],
#  ['log in the invoice number and click on search',
#   ('log in', 'invoice number', ''),
#   ('click', 'search', '')],
#  ['enter the invoice number and select on search',
#   ('enter', 'invoice number', ''),
#   ('select', 'search', '')],
#  ['enter the invoice number and deselect on search',
#   ('enter', 'invoice number', ''),
#   ('deselect', 'search', '')],
#  ['Check the Validation Status', ('check', 'Validation Status', '')],
#  ['Navigate to Payables - > Payments and select Manage Payments',
#   ('navigate', 'Payables', ''),
#   ('navigate', 'payments', ''),
#   ('select', 'manage payments', '')],
#  ['navigate to payables - > payments and click manage payments',
#   ('navigate', 'Payables', ''),
#   ('navigate', 'payments', ''),
#   ('click', 'manage payments', '')],
#  ['navigate to payables - > payments and deselect manage payments',
#   ('navigate', 'Payables', ''),
#   ('navigate', 'payments', ''),
#   ('deselect', 'manage payments', '')],
#  ['go to to payables - > payments and select manage payments',
#   ('go to', 'Payables', ''),
#   ('go to', 'payments', ''),
#   ('select', 'manage payments', '')],
#  ['on to payables - > payments and select manage payments',
#   ('on', 'Payables', ''),
#   ('on', 'payments', ''),
#   ('select', 'manage payments', '')],
#  ['Enter the payment date and click on search',
#   ('enter', 'payment date', ''),
#   ('click', 'search', '')],
#  ['login the payment date and click on search',
#   ('login', 'payment date', ''),
#   ('click', 'search', '')],
#  ['log in the payment date and click on search',
#   ('log in', 'payment date', ''),
#   ('click', 'search', '')],
#  ['enter the payment date and select on search',
#   ('enter', 'payment date', ''),
#   ('select', 'search', '')],
#  ['enter the payment date and deselect on search',
#   ('enter', 'payment date', ''),
#   ('deselect', 'search', '')],
#  ['Select the Payment Line with Payment Number 5599 and Click on the Payment number',
#   ('select', 'payment line', '5599'),
#   ('click', 'Payment number', '')],
#  ['click the payment line with payment number 5599 and click on the payment number',
#   ('click', 'payment line', '5599'),
#   ('click', 'Payment number', '')],
#  ['deselect the payment line with payment number 5599 and click on the payment number',
#   ('deselect', 'payment line', '5599'),
#   ('click', 'Payment number', '')],
#  ['select the payment line with payment number 5599 and select on the payment number',
#   ('select', 'payment line', '5599'),
#   ('select', 'Payment number', '')],
#  ['select the payment line with payment number 5599 and deselect on the payment number',
#   ('select', 'payment line', '5599'),
#   ('deselect', 'Payment number', '')],
#  ["Click ' Actions ' dropdown and select ' Void '",
#   ('click', 'action', ''),
#   ('select', 'void', '')],
#  ["click ' actions ' dropdown and click ' void '",
#   ('click', 'action', ''),
#   ('click', 'void', '')],
#  ["click ' actions ' dropdown and deselect ' void '",
#   ('click', 'action', ''),
#   ('deselect', 'void', '')],
#  ["select ' actions ' dropdown and select ' void '",
#   ('select', 'action', ''),
#   ('select', 'void', '')],
#  ["deselect ' actions ' dropdown and select ' void '",
#   ('deselect', 'action', ''),
#   ('select', 'void', '')],
#  ['Select the reason : Cancel Invoice and click on OK',
#   ('select', 'Cancel Invoice', ''),
#   ('click', 'ok', '')],
#  ['click the reason : cancel invoice and click on ok',
#   ('click', 'Cancel Invoice', ''),
#   ('click', 'ok', '')],
#  ['deselect the reason : cancel invoice and click on ok',
#   ('deselect', 'Cancel Invoice', ''),
#   ('click', 'ok', '')],
#  ['select the reason : cancel invoice and select on ok',
#   ('select', 'Cancel Invoice', ''),
#   ('select', 'ok', '')],
#  ['select the reason : cancel invoice and deselect on ok',
#   ('select', 'Cancel Invoice', ''),
#   ('deselect', 'ok', '')],
#  ['select the reason : cancel invoice and click on complete',
#   ('select', 'Cancel Invoice', ''),
#   ('click', 'complete', '')],
#  ['Select the Payment Line with Payment Number and Click on the Payment number',
#   ('select', 'payment line', ''),
#   ('click', 'Payment number', '')],
#  ['click the payment line with payment number and click on the payment number',
#   ('click', 'payment line', ''),
#   ('click', 'Payment number', '')],
#  ['deselect the payment line with payment number and click on the payment number',
#   ('deselect', 'payment line', ''),
#   ('click', 'Payment number', '')],
#  ['select the payment line with payment number and select on the payment number',
#   ('select', 'payment line', ''),
#   ('select', 'Payment number', '')],
#  ['select the payment line with payment number and deselect on the payment number',
#   ('select', 'payment line', ''),
#   ('deselect', 'Payment number', '')],
#  ["Click ' Actions ' dropdown and select ' View Accounting '",
#   ('click', 'action', ''),
#   ('select', 'view accounting', '')],
#  ["click ' actions ' dropdown and click ' view accounting '",
#   ('click', 'action', ''),
#   ('click', 'view accounting', '')],
#  ["click ' actions ' dropdown and deselect ' view accounting '",
#   ('click', 'action', ''),
#   ('deselect', 'view accounting', '')],
#  ["select ' actions ' dropdown and select ' view accounting '",
#   ('select', 'action', ''),
#   ('select', 'view accounting', '')],
#  ["deselect ' actions ' dropdown and select ' view accounting '",
#   ('deselect', 'action', ''),
#   ('select', 'view accounting', '')],
#  ['Select the Payment Line with Payment Number 5738 and Click on the Payment number',
#   ('select', 'payment line', '5738'),
#   ('click', 'Payment number', '')],
#  ['click the payment line with payment number 5738 and click on the payment number',
#   ('click', 'payment line', '5738'),
#   ('click', 'Payment number', '')],
#  ['deselect the payment line with payment number 5738 and click on the payment number',
#   ('deselect', 'payment line', '5738'),
#   ('click', 'Payment number', '')],
#  ['select the payment line with payment number 5738 and select on the payment number',
#   ('select', 'payment line', '5738'),
#   ('select', 'Payment number', '')],
#  ['select the payment line with payment number 5738 and deselect on the payment number',
#   ('select', 'payment line', '5738'),
#   ('deselect', 'Payment number', '')],
#  ['Click on Ok to Void for No Reason', ('click', 'ok', '')],
#  ['select on ok to void for no reason', ('select', 'ok', '')],
#  ['deselect on ok to void for no reason', ('deselect', 'ok', '')],
#  ['click on complete to void for no reason', ('click', 'complete', '')],
#  ["Click ' Actions ' dropdown and select ' Account in Draft '",
#   ('click', 'actions', ''),
#   ('select', 'Account in Draft', '')],
#  ["click ' actions ' dropdown and click ' account in draft '",
#   ('click', 'actions', ''),
#   ('click', 'Account in Draft', '')],
#  ["click ' actions ' dropdown and deselect ' account in draft '",
#   ('click', 'actions', ''),
#   ('deselect', 'Account in Draft', '')],
#  ["select ' actions ' dropdown and select ' account in draft '",
#   ('select', 'actions', ''),
#   ('select', 'Account in Draft', '')],
#  ["deselect ' actions ' dropdown and select ' account in draft '",
#   ('deselect', 'actions', ''),
#   ('select', 'Account in Draft', '')],
#  ['Click on View Accounting Entries', ('click', 'view', '')],
#  ['select on view accounting entries', ('select', 'view', '')],
#  ['deselect on view accounting entries', ('deselect', 'view', '')],
#  ["Click ' Actions ' dropdown and select ' Post to Ledger '",
#   ('click', 'actions', ''),
#   ('select', 'Post to Ledger', '')],
#  ["click ' actions ' dropdown and click ' post to ledger '",
#   ('click', 'actions', ''),
#   ('click', 'Post to Ledger', '')],
#  ["click ' actions ' dropdown and deselect ' post to ledger '",
#   ('click', 'actions', ''),
#   ('deselect', 'Post to Ledger', '')],
#  ["select ' actions ' dropdown and select ' post to ledger '",
#   ('select', 'actions', ''),
#   ('select', 'Post to Ledger', '')],
#  ["deselect ' actions ' dropdown and select ' post to ledger '",
#   ('deselect', 'actions', ''),
#   ('select', 'Post to Ledger', '')],
#  ['Select the Payment Line with Payment Number 5738 and Click on the Payment number',
#   ('select', 'payment line', '5738'),
#   ('click', 'payment number', '')],
#  ['click the payment line with payment number 5738 and click on the payment number',
#   ('click', 'payment line', '5738'),
#   ('click', 'payment number', '')],
#  ['deselect the payment line with payment number 5738 and click on the payment number',
#   ('deselect', 'payment line', '5738'),
#   ('click', 'payment number', '')],
#  ['select the payment line with payment number 5738 and select on the payment number',
#   ('select', 'payment line', '5738'),
#   ('select', 'payment number', '')],
#  ['select the payment line with payment number 5738 and deselect on the payment number',
#   ('select', 'payment line', '5738'),
#   ('deselect', 'payment number', '')],
#  ['Navigate to Payables - > Invoices',
#   ('navigate', 'payables', ''),
#   ('navigate', 'invoices', '')],
#  ['go to to payables - > invoices',
#   ('go to', 'payables', ''),
#   ('go to', 'invoices', '')],
#  ['on to payables - > invoices',
#   ('on', 'payables', ''),
#   ('on', 'invoices', '')],
#  ['Click on Task icon and click on Manage Invoices',
#   ('click', 'task icon', ''),
#   ('click', 'manage invoices', '')],
#  ['select on task icon and select on manage invoices',
#   ('select', 'task icon', ''),
# ...
#  ['validate for lab batch type selection , the following are displayed : \n - reason for this batch * : displays : select reason for this batch \n - optional equipment : displays : select optional equipment \n \n capture and attach screen print : equipment information section',
#   ('validate', 'selection', 'Lab Batch Type'),
#   ('validate', 'Reason for this Batch', ''),
#   ('validate', 'Optional Equipment', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['Select the Batch Type as Pilot and verify the following are displayed : \n - Equipment * : displays : Select Equipment \n - Optional Equipment : displays : Select Optional Equipment \n - Reason for this Batch : displays : Reason \n Capture and attach screen print : Equipment Information section',
#   ('select', 'batch type', 'pilot'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'optional equipment', ''),
#   ('verify', 'reason', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['click the batch type as pilot and verify the following are displayed : \n - equipment * : displays : click equipment \n - optional equipment : displays : click optional equipment \n - reason for this batch : displays : reason \n capture and attach screen print : equipment information section',
#   ('click', 'batch type', 'pilot'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'optional equipment', ''),
#   ('verify', 'reason', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['deselect the batch type as pilot and verify the following are displayed : \n - equipment * : displays : deselect equipment \n - optional equipment : displays : deselect optional equipment \n - reason for this batch : displays : reason \n capture and attach screen print : equipment information section',
#   ('deselect', 'batch type', 'pilot'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'optional equipment', ''),
#   ('verify', 'reason', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['select the batch type as pilot and validate the following are displayed : \n - equipment * : displays : select equipment \n - optional equipment : displays : select optional equipment \n - reason for this batch : displays : reason \n capture and attach screen print : equipment information section',
#   ('select', 'batch type', 'pilot'),
#   ('validate', 'Equipment', ''),
#   ('validate', 'optional equipment', ''),
#   ('validate', 'reason', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['Select the Batch Type as Other and verify the following are displayed : \n - Equipment * : displays : Select Equipment \n - Reason for this Batch * : displays : Reason \n Capture and attach screen print : Equipment Information section',
#   ('select', 'batch type', 'other'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'Reason for this Batch', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['click the batch type as other and verify the following are displayed : \n - equipment * : displays : click equipment \n - reason for this batch * : displays : reason \n capture and attach screen print : equipment information section',
#   ('click', 'batch type', 'other'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'Reason for this Batch', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['deselect the batch type as other and verify the following are displayed : \n - equipment * : displays : deselect equipment \n - reason for this batch * : displays : reason \n capture and attach screen print : equipment information section',
#   ('deselect', 'batch type', 'other'),
#   ('verify', 'Equipment', ''),
#   ('verify', 'Reason for this Batch', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['select the batch type as other and validate the following are displayed : \n - equipment * : displays : select equipment \n - reason for this batch * : displays : reason \n capture and attach screen print : equipment information section',
#   ('select', 'batch type', 'other'),
#   ('validate', 'Equipment', ''),
#   ('validate', 'Reason for this Batch', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['Select Site / Legal Product Category / Batch Type as VDR / Cosmetic / Lab , verify the following : \n - Reason for this Batch : Multi - select dropdown with alphabetical order of values , select more than one value \n - Optional Equipment : Dropdown list , select any value . \n Capture and attach screen print : Equipment Information section',
#   ('select', 'Site', 'VDR / Cosmetic / Lab'),
#   ('select', 'Legal Product Category', 'VDR / Cosmetic / Lab'),
#   ('select', 'Batch Type', 'VDR / Cosmetic / Lab'),
#   ('verify', 'Reason for this Batch', ''),
#   ('verify', 'Optional Equipment', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['click site / legal product category / batch type as vdr / cosmetic / lab , verify the following : \n - reason for this batch : multi - click dropdown with alphabetical order of values , click more than one value \n - optional equipment : dropdown list , click any value . \n capture and attach screen print : equipment information section',
#   ('click', 'Site', 'VDR / Cosmetic / Lab'),
#   ('click', 'Legal Product Category', 'VDR / Cosmetic / Lab'),
#   ('click', 'Batch Type', 'VDR / Cosmetic / Lab'),
#   ('verify', 'Reason for this Batch', ''),
#   ('verify', 'Optional Equipment', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['deselect site / legal product category / batch type as vdr / cosmetic / lab , verify the following : \n - reason for this batch : multi - deselect dropdown with alphabetical order of values , deselect more than one value \n - optional equipment : dropdown list , deselect any value . \n capture and attach screen print : equipment information section',
#   ('deselect', 'Site', 'VDR / Cosmetic / Lab'),
#   ('deselect', 'Legal Product Category', 'VDR / Cosmetic / Lab'),
#   ('deselect', 'Batch Type', 'VDR / Cosmetic / Lab'),
#   ('verify', 'Reason for this Batch', ''),
#   ('verify', 'Optional Equipment', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['select site / legal product category / batch type as vdr / cosmetic / lab , validate the following : \n - reason for this batch : multi - select dropdown with alphabetical order of values , select more than one value \n - optional equipment : dropdown list , select any value . \n capture and attach screen print : equipment information section',
#   ('select', 'Site', 'VDR / Cosmetic / Lab'),
#   ('select', 'Legal Product Category', 'VDR / Cosmetic / Lab'),
#   ('select', 'Batch Type', 'VDR / Cosmetic / Lab'),
#   ('validate', 'Reason for this Batch', ''),
#   ('validate', 'Optional Equipment', ''),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['Save the request . \n Click the Ok button . \n Navigate to Book Equipment in Calendar section and verify the following is displayed : \n - Label : Calendar for Lab \n - <Optional Equipment selected in step 9> \n - Calendar display for the current date <Month DD , YYYY> with Bench listing for VRD / Cosmetic / Lab per Test Prerequisite 3 \n - Date field : populated with the current date and enabled to choose dates later than current date \n Capture and attach screen print : Message , Calendar for Lab section , Test Prerequisite 3',
#   ('save', 'request', ''),
#   ('click', 'OK button', ''),
#   ('navigate', 'book equipment', ''),
#   ('verify', 'label', ''),
#   ('verify', 'calendar', 'current date'),
#   ('verify', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('verify', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['save the request . \n click the ok button . \n navigate to book equipment in calendar section and validate the following is displayed : \n - label : calendar for lab \n - <optional equipment selected in step 9> \n - calendar display for the current date <month dd , yyyy> with bench listing for vrd / cosmetic / lab per test prerequisite 3 \n - date field : populated with the current date and enabled to choose dates later than current date \n capture and attach screen print : message , calendar for lab section , test prerequisite 3',
#   ('save', 'request', ''),
#   ('click', 'OK button', ''),
#   ('navigate', 'book equipment', ''),
#   ('validate', 'label', ''),
#   ('validate', 'calendar', 'current date'),
#   ('validate', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('validate', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['save the request . \n click the ok button . \n go to to book equipment in calendar section and verify the following is displayed : \n - label : calendar for lab \n - <optional equipment selected in step 9> \n - calendar display for the current date <month dd , yyyy> with bench listing for vrd / cosmetic / lab per test prerequisite 3 \n - date field : populated with the current date and enabled to choose dates later than current date \n capture and attach screen print : message , calendar for lab section , test prerequisite 3',
#   ('save', 'request', ''),
#   ('click', 'OK button', ''),
#   ('go to', 'book equipment', ''),
#   ('verify', 'label', ''),
#   ('verify', 'calendar', 'current date'),
#   ('verify', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('verify', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['save the request . \n click the ok button . \n on to book equipment in calendar section and verify the following is displayed : \n - label : calendar for lab \n - <optional equipment selected in step 9> \n - calendar display for the current date <month dd , yyyy> with bench listing for vrd / cosmetic / lab per test prerequisite 3 \n - date field : populated with the current date and enabled to choose dates later than current date \n capture and attach screen print : message , calendar for lab section , test prerequisite 3',
#   ('save', 'request', ''),
#   ('click', 'OK button', ''),
#   ('on', 'book equipment', ''),
#   ('verify', 'label', ''),
#   ('verify', 'calendar', 'current date'),
#   ('verify', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('verify', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['save the request . \n select the ok button . \n navigate to book equipment in calendar section and verify the following is displayed : \n - label : calendar for lab \n - <optional equipment selected in step 9> \n - calendar display for the current date <month dd , yyyy> with bench listing for vrd / cosmetic / lab per test prerequisite 3 \n - date field : populated with the current date and enabled to choose dates later than current date \n capture and attach screen print : message , calendar for lab section , test prerequisite 3',
#   ('save', 'request', ''),
#   ('select', 'OK button', ''),
#   ('navigate', 'book equipment', ''),
#   ('verify', 'label', ''),
#   ('verify', 'calendar', 'current date'),
#   ('verify', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('verify', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['save the request . \n deselect the ok button . \n navigate to book equipment in calendar section and verify the following is displayed : \n - label : calendar for lab \n - <optional equipment selected in step 9> \n - calendar display for the current date <month dd , yyyy> with bench listing for vrd / cosmetic / lab per test prerequisite 3 \n - date field : populated with the current date and enabled to choose dates later than current date \n capture and attach screen print : message , calendar for lab section , test prerequisite 3',
#   ('save', 'request', ''),
#   ('deselect', 'OK button', ''),
#   ('navigate', 'book equipment', ''),
#   ('verify', 'label', ''),
#   ('verify', 'calendar', 'current date'),
#   ('verify', 'bench listing', 'VRD / Cosmetic / Lab'),
#   ('verify', 'date field', 'current date'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['Using the Test Prerequisite 2 , navigate to the Manufacturing Date for the Lab Batch Type request (Test Setup 1a) with status Reserved . \n Verify per Test Prerequisite 2 the following is displayed for the request \n - Requested By \n - Batch Request # \n - Formula # \n - Department \n - Project Name \n - Description \n - Word Order # \n - Reason \n - Filling quantities (Tubes , Bottles , Jars) \n Capture and attach screen print : Calendar for Lab section',
#   ('navigate', 'Manufacturing Date', ''),
#   ('verify', 'Requested By', ''),
#   ('verify', 'batch request', ''),
#   ('verify', 'formula', ''),
#   ('verify', 'department', ''),
#   ('verify', 'project name', ''),
#   ('verify', 'description', ''),
#   ('verify', 'word order', ''),
#   ('verify', 'reason', ''),
#   ('verify', 'filling quantities', 'Tubes'),
#   ('verify', 'filling quantities', 'Bottles'),
#   ('verify', 'filling quantities', 'Jars'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['using the test prerequisite 2 , navigate to the manufacturing date for the lab batch type request (test setup 1a) with status reserved . \n validate per test prerequisite 2 the following is displayed for the request \n - requested by \n - batch request # \n - formula # \n - department \n - project name \n - description \n - word order # \n - reason \n - filling quantities (tubes , bottles , jars) \n capture and attach screen print : calendar for lab section',
#   ('navigate', 'Manufacturing Date', ''),
#   ('validate', 'Requested By', ''),
#   ('validate', 'batch request', ''),
#   ('validate', 'formula', ''),
#   ('validate', 'department', ''),
#   ('validate', 'project name', ''),
#   ('validate', 'description', ''),
#   ('validate', 'word order', ''),
#   ('validate', 'reason', ''),
#   ('validate', 'filling quantities', 'Tubes'),
#   ('validate', 'filling quantities', 'Bottles'),
#   ('validate', 'filling quantities', 'Jars'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['using the test prerequisite 2 , go to to the manufacturing date for the lab batch type request (test setup 1a) with status reserved . \n verify per test prerequisite 2 the following is displayed for the request \n - requested by \n - batch request # \n - formula # \n - department \n - project name \n - description \n - word order # \n - reason \n - filling quantities (tubes , bottles , jars) \n capture and attach screen print : calendar for lab section',
#   ('go to', 'Manufacturing Date', ''),
#   ('verify', 'Requested By', ''),
#   ('verify', 'batch request', ''),
#   ('verify', 'formula', ''),
#   ('verify', 'department', ''),
#   ('verify', 'project name', ''),
#   ('verify', 'description', ''),
#   ('verify', 'word order', ''),
#   ('verify', 'reason', ''),
#   ('verify', 'filling quantities', 'Tubes'),
#   ('verify', 'filling quantities', 'Bottles'),
#   ('verify', 'filling quantities', 'Jars'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')],
#  ['using the test prerequisite 2 , on to the manufacturing date for the lab batch type request (test setup 1a) with status reserved . \n verify per test prerequisite 2 the following is displayed for the request \n - requested by \n - batch request # \n - formula # \n - department \n - project name \n - description \n - word order # \n - reason \n - filling quantities (tubes , bottles , jars) \n capture and attach screen print : calendar for lab section',
#   ('on', 'Manufacturing Date', ''),
#   ('verify', 'Requested By', ''),
#   ('verify', 'batch request', ''),
#   ('verify', 'formula', ''),
#   ('verify', 'department', ''),
#   ('verify', 'project name', ''),
#   ('verify', 'description', ''),
#   ('verify', 'word order', ''),
#   ('verify', 'reason', ''),
#   ('verify', 'filling quantities', 'Tubes'),
#   ('verify', 'filling quantities', 'Bottles'),
#   ('verify', 'filling quantities', 'Jars'),
#   ('capture', 'screen print', ''),
#   ('attach', 'screen print', '')]]

# %%
# def check_presense(text, item_list):
#     if text in item_list: return True
#     for item in item_list:
#         if text in item.split(" "): return True
#     return False

# def prepare_data_for_training(data_list):
#     for item in data_list:
#         tag_list = []
#         text, triplets = item[0], item[1:]
#         token_list = text.lower().split(" ")
#         tag_list = ["O" for i in range(len(token_list))]
#         unique_actions, unique_labels, unique_data = set(), set(), set()
        
#         for action, label, data in triplets:
#             if action: unique_actions.add(action.lower())
#             if label: unique_labels.add(label.lower())
#             if data: unique_data.add(data.lower())
                
#         for i in range(len(token_list)):
#             val = token_list[i]
#             #if val.lower() in unique_actions: tag_list[i] = "action"
#             #if val.lower() in unique_labels: tag_list[i] = "label"
#             #if val.lower() in unique_data: tag_list[i] = "data"
#             if check_presense(val.lower(), unique_actions):tag_list[i] = "action"
#             if check_presense(val.lower(), unique_labels):tag_list[i] = "label"
#             if check_presense(val.lower(), unique_data):tag_list[i] = "data"
#         processed_data.append((token_list, tag_list))
        
# prepare_data_for_training(preprocess_list)

# %%
def prepare_char_index_map(string):
    d1, i = {0:0}, 1
    for index, char in enumerate(string):
        if char == " ":
            d1[index+1] = i
            i+=1
    return d1

errors = 0

def populate_tag_list(char_index_map, text, token_list, tag_list, val, label):
    
    index, i, occurrence = "", "", ""
    try:
        if len(val.split(" ")) == 1:
            for index, x in enumerate(token_list):
                if x == val: tag_list[index] = label
        else:
            occurrence = text.find(val)
            words = val.split(" ")
            index = char_index_map[occurrence]
            for i, word in enumerate(words):
                if token_list[index+i] == word:
                    tag_list[index+i] = label
                else:
                    raise Exception
    except Exception as e:
        #pass
        print(words, token_list, index, i)
        print(occurrence)
        print(text)
        print(char_index_map)
        global errors
        errors += 1
        print("=-------------", errors)

def prepare_data_for_training(data_list):
    processed_data = []
    for item in data_list:
        text, triplets = item[0], item[1:]
        token_list = text.lower().split(" ")
        char_index_map = prepare_char_index_map(text.lower())
        tag_list = ["O" for i in range(len(token_list))]
        
        unique_actions, unique_labels, unique_data = set(), set(), set()
        for action, label, data in triplets:
            if action: unique_actions.add(action.lower())
            if label: unique_labels.add(label.lower())
            if data: unique_data.add(data.lower())
                
        for action in unique_actions:
            populate_tag_list(char_index_map, text.lower(), token_list, tag_list, action, "action")
            
        for label in unique_labels:
            populate_tag_list(char_index_map, text.lower(), token_list, tag_list, label, "label")
            
        for data in unique_data:
            populate_tag_list(char_index_map, text.lower(), token_list, tag_list, data, "data")
            
        #print(token_list)
        #print(tag_list)
        #print("\n")
        processed_data.append((token_list, tag_list))
    
    return processed_data
        

processed_data = prepare_data_for_training(augmented_list)

# %%
l1 = [['click the following for the equipment information section : \n a . - site \n b . - legal product category', ('click', 'site', ''), ('click', 'Legal Product Category', '')]]

print(l1)

l2 = prepare_data_for_training(l1)

print(l2)
# Out:
# [['click the following for the equipment information section : \n a . - site \n b . - legal product category', ('click', 'site', ''), ('click', 'Legal Product Category', '')]]
# [(['click', 'the', 'following', 'for', 'the', 'equipment', 'information', 'section', ':', '\n', 'a', '.', '-', 'site', '\n', 'b', '.', '-', 'legal', 'product', 'category'], ['action', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'label', 'O', 'O', 'O', 'O', 'label', 'label', 'label'])]

# %%
for index, x in enumerate(processed_data):
    print(augmented_list[index])
    print(list(zip(x[0], x[1])))
    print("\n")
    if index == 50: break
# Out:
# ['Select Asset Class as " CC " and select Deal Type as " TRADE CC "', ('select', 'Asset Class', 'CC'), ('select', 'Deal Type', 'TRADE CC')]
# [('select', 'action'), ('asset', 'label'), ('class', 'label'), ('as', 'O'), ('"', 'O'), ('cc', 'data'), ('"', 'O'), ('and', 'O'), ('select', 'action'), ('deal', 'label'), ('type', 'label'), ('as', 'O'), ('"', 'O'), ('trade', 'data'), ('cc', 'data'), ('"', 'O')]
#
#
# ['click asset class as " cc " and click deal type as " trade cc "', ('click', 'Asset Class', 'CC'), ('click', 'Deal Type', 'TRADE CC')]
# [('click', 'action'), ('asset', 'label'), ('class', 'label'), ('as', 'O'), ('"', 'O'), ('cc', 'data'), ('"', 'O'), ('and', 'O'), ('click', 'action'), ('deal', 'label'), ('type', 'label'), ('as', 'O'), ('"', 'O'), ('trade', 'data'), ('cc', 'data'), ('"', 'O')]
#
#
# ['deselect asset class as " cc " and deselect deal type as " trade cc "', ('deselect', 'Asset Class', 'CC'), ('deselect', 'Deal Type', 'TRADE CC')]
# [('deselect', 'action'), ('asset', 'label'), ('class', 'label'), ('as', 'O'), ('"', 'O'), ('cc', 'data'), ('"', 'O'), ('and', 'O'), ('deselect', 'action'), ('deal', 'label'), ('type', 'label'), ('as', 'O'), ('"', 'O'), ('trade', 'data'), ('cc', 'data'), ('"', 'O')]
#
#
# ['Select the following for the Equipment Information section : \n a . - Site \n b . - Legal Product Category', ('select', 'site', ''), ('select', 'Legal Product Category', '')]
# [('select', 'action'), ('the', 'O'), ('following', 'O'), ('for', 'O'), ('the', 'O'), ('equipment', 'O'), ('information', 'O'), ('section', 'O'), (':', 'O'), ('\n', 'O'), ('a', 'O'), ('.', 'O'), ('-', 'O'), ('site', 'label'), ('\n', 'O'), ('b', 'O'), ('.', 'O'), ('-', 'O'), ('legal', 'label'), ('product', 'label'), ('category', 'label')]
#
#
# ['click the following for the equipment information section : \n a . - site \n b . - legal product category', ('click', 'site', ''), ('click', 'Legal Product Category', '')]
# [('click', 'action'), ('the', 'O'), ('following', 'O'), ('for', 'O'), ('the', 'O'), ('equipment', 'O'), ('information', 'O'), ('section', 'O'), (':', 'O'), ('\n', 'O'), ('a', 'O'), ('.', 'O'), ('-', 'O'), ('site', 'label'), ('\n', 'O'), ('b', 'O'), ('.', 'O'), ('-', 'O'), ('legal', 'label'), ('product', 'label'), ('category', 'label')]
#
#
# ['deselect the following for the equipment information section : \n a . - site \n b . - legal product category', ('deselect', 'site', ''), ('deselect', 'Legal Product Category', '')]
# [('deselect', 'action'), ('the', 'O'), ('following', 'O'), ('for', 'O'), ('the', 'O'), ('equipment', 'O'), ('information', 'O'), ('section', 'O'), (':', 'O'), ('\n', 'O'), ('a', 'O'), ('.', 'O'), ('-', 'O'), ('site', 'label'), ('\n', 'O'), ('b', 'O'), ('.', 'O'), ('-', 'O'), ('legal', 'label'), ('product', 'label'), ('category', 'label')]
#
#
# ["Go to ' Action ' dropdown and select ' Pay in Full '", ('select', 'action', 'Pay in Full')]
# [('go', 'O'), ('to', 'O'), ("'", 'O'), ('action', 'label'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('select', 'action'), ("'", 'O'), ('pay', 'data'), ('in', 'data'), ('full', 'data'), ("'", 'O')]
#
#
# ["go to ' action ' dropdown and click ' pay in full '", ('click', 'action', 'Pay in Full')]
# [('go', 'O'), ('to', 'O'), ("'", 'O'), ('action', 'label'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('click', 'action'), ("'", 'O'), ('pay', 'data'), ('in', 'data'), ('full', 'data'), ("'", 'O')]
#
#
# ["go to ' action ' dropdown and deselect ' pay in full '", ('deselect', 'action', 'Pay in Full')]
# [('go', 'O'), ('to', 'O'), ("'", 'O'), ('action', 'label'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('deselect', 'action'), ("'", 'O'), ('pay', 'data'), ('in', 'data'), ('full', 'data'), ("'", 'O')]
#
#
# ["Click ' Actions ' dropdown and select ' Post to Ledger '", ('select', 'action', 'Post to Ledger')]
# [('click', 'O'), ("'", 'O'), ('actions', 'O'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('select', 'action'), ("'", 'O'), ('post', 'data'), ('to', 'data'), ('ledger', 'data'), ("'", 'O')]
#
#
# ["click ' actions ' dropdown and click ' post to ledger '", ('click', 'action', 'Post to Ledger')]
# [('click', 'action'), ("'", 'O'), ('actions', 'O'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('click', 'action'), ("'", 'O'), ('post', 'data'), ('to', 'data'), ('ledger', 'data'), ("'", 'O')]
#
#
# ["click ' actions ' dropdown and deselect ' post to ledger '", ('deselect', 'action', 'Post to Ledger')]
# [('click', 'O'), ("'", 'O'), ('actions', 'O'), ("'", 'O'), ('dropdown', 'O'), ('and', 'O'), ('deselect', 'action'), ("'", 'O'), ('post', 'data'), ('to', 'data'), ('ledger', 'data'), ("'", 'O')]
#
#
# ['Select branch name as " Retail Branch " , Rep Name as " Retail . io " and click on login', ('select', 'branch name', 'Retail Branch'), ('select', 'Rep Name', 'Retail . io'), ('click', 'login', '')]
# [('select', 'action'), ('branch', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('branch', 'data'), ('"', 'O'), (',', 'O'), ('rep', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('.', 'data'), ('io', 'data'), ('"', 'O'), ('and', 'O'), ('click', 'action'), ('on', 'O'), ('login', 'label')]
#
#
# ['click branch name as " retail branch " , rep name as " retail . io " and click on login', ('click', 'branch name', 'Retail Branch'), ('click', 'Rep Name', 'Retail . io'), ('click', 'login', '')]
# [('click', 'action'), ('branch', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('branch', 'data'), ('"', 'O'), (',', 'O'), ('rep', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('.', 'data'), ('io', 'data'), ('"', 'O'), ('and', 'O'), ('click', 'action'), ('on', 'O'), ('login', 'label')]
#
#
# ['deselect branch name as " retail branch " , rep name as " retail . io " and click on login', ('deselect', 'branch name', 'Retail Branch'), ('deselect', 'Rep Name', 'Retail . io'), ('click', 'login', '')]
# [('deselect', 'action'), ('branch', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('branch', 'data'), ('"', 'O'), (',', 'O'), ('rep', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('.', 'data'), ('io', 'data'), ('"', 'O'), ('and', 'O'), ('click', 'action'), ('on', 'O'), ('login', 'label')]
#
#
# ['select branch name as " retail branch " , rep name as " retail . io " and select on login', ('select', 'branch name', 'Retail Branch'), ('select', 'Rep Name', 'Retail . io'), ('select', 'login', '')]
# [('select', 'action'), ('branch', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('branch', 'data'), ('"', 'O'), (',', 'O'), ('rep', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('.', 'data'), ('io', 'data'), ('"', 'O'), ('and', 'O'), ('select', 'action'), ('on', 'O'), ('login', 'label')]
#
#
# ['select branch name as " retail branch " , rep name as " retail . io " and deselect on login', ('select', 'branch name', 'Retail Branch'), ('select', 'Rep Name', 'Retail . io'), ('deselect', 'login', '')]
# [('select', 'action'), ('branch', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('branch', 'data'), ('"', 'O'), (',', 'O'), ('rep', 'label'), ('name', 'label'), ('as', 'O'), ('"', 'O'), ('retail', 'data'), ('.', 'data'), ('io', 'data'), ('"', 'O'), ('and', 'O'), ('deselect', 'action'), ('on', 'O'), ('login', 'label')]
#
#
# ['Select the reason : Cancel Invoice', ('select', 'reason', 'cancel invoice')]
# [('select', 'action'), ('the', 'O'), ('reason', 'label'), (':', 'O'), ('cancel', 'data'), ('invoice', 'data')]
#
#
# ['click the reason : cancel invoice', ('click', 'reason', 'cancel invoice')]
# [('click', 'action'), ('the', 'O'), ('reason', 'label'), (':', 'O'), ('cancel', 'data'), ('invoice', 'data')]
#
#
# ['deselect the reason : cancel invoice', ('deselect', 'reason', 'cancel invoice')]
# [('deselect', 'action'), ('the', 'O'), ('reason', 'label'), (':', 'O'), ('cancel', 'data'), ('invoice', 'data')]
#
#
# ['Assign voice lines to the user and Enter " test1222 " in username input', ('assign', 'user', 'voice lines'), ('enter', 'username', 'test1222')]
# [('assign', 'action'), ('voice', 'data'), ('lines', 'data'), ('to', 'O'), ('the', 'O'), ('user', 'label'), ('and', 'O'), ('enter', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['assign voice lines to the user and login " test1222 " in username input', ('assign', 'user', 'voice lines'), ('login', 'username', 'test1222')]
# [('assign', 'action'), ('voice', 'data'), ('lines', 'data'), ('to', 'O'), ('the', 'O'), ('user', 'label'), ('and', 'O'), ('login', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['assign voice lines to the user and log in " test1222 " in username input', ('assign', 'user', 'voice lines'), ('log in', 'username', 'test1222')]
# [('assign', 'action'), ('voice', 'data'), ('lines', 'data'), ('to', 'O'), ('the', 'O'), ('user', 'label'), ('and', 'O'), ('log', 'action'), ('in', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['assign voice lines to the user and enter " test1222 " in user name input', ('assign', 'user', 'voice lines'), ('enter', 'user name', 'test1222')]
# [('assign', 'action'), ('voice', 'data'), ('lines', 'data'), ('to', 'O'), ('the', 'O'), ('user', 'label'), ('and', 'O'), ('enter', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('user', 'label'), ('name', 'label'), ('input', 'O')]
#
#
# ['On select user , selected data should be showed', ('select', '', 'user')]
# [('on', 'O'), ('select', 'action'), ('user', 'data'), (',', 'O'), ('selected', 'O'), ('data', 'O'), ('should', 'O'), ('be', 'O'), ('showed', 'O')]
#
#
# ['on click user , clicked data should be showed', ('click', '', 'user')]
# [('on', 'O'), ('click', 'action'), ('user', 'data'), (',', 'O'), ('clicked', 'O'), ('data', 'O'), ('should', 'O'), ('be', 'O'), ('showed', 'O')]
#
#
# ['on deselect user , deselected data should be showed', ('deselect', '', 'user')]
# [('on', 'O'), ('deselect', 'action'), ('user', 'data'), (',', 'O'), ('deselected', 'O'), ('data', 'O'), ('should', 'O'), ('be', 'O'), ('showed', 'O')]
#
#
# ['Verify country dropdown is on the page and select india after opening the dropdown', ('verify', 'country', ''), ('select', '', 'india')]
# [('verify', 'action'), ('country', 'label'), ('dropdown', 'O'), ('is', 'O'), ('on', 'O'), ('the', 'O'), ('page', 'O'), ('and', 'O'), ('select', 'action'), ('india', 'data'), ('after', 'O'), ('opening', 'O'), ('the', 'O'), ('dropdown', 'O')]
#
#
# ['verify country dropdown is on the page and click india after opening the dropdown', ('verify', 'country', ''), ('click', '', 'india')]
# [('verify', 'action'), ('country', 'label'), ('dropdown', 'O'), ('is', 'O'), ('on', 'O'), ('the', 'O'), ('page', 'O'), ('and', 'O'), ('click', 'action'), ('india', 'data'), ('after', 'O'), ('opening', 'O'), ('the', 'O'), ('dropdown', 'O')]
#
#
# ['verify country dropdown is on the page and deselect india after opening the dropdown', ('verify', 'country', ''), ('deselect', '', 'india')]
# [('verify', 'action'), ('country', 'label'), ('dropdown', 'O'), ('is', 'O'), ('on', 'O'), ('the', 'O'), ('page', 'O'), ('and', 'O'), ('deselect', 'action'), ('india', 'data'), ('after', 'O'), ('opening', 'O'), ('the', 'O'), ('dropdown', 'O')]
#
#
# ['validate country dropdown is on the page and select india after opening the dropdown', ('validate', 'country', ''), ('select', '', 'india')]
# [('validate', 'action'), ('country', 'label'), ('dropdown', 'O'), ('is', 'O'), ('on', 'O'), ('the', 'O'), ('page', 'O'), ('and', 'O'), ('select', 'action'), ('india', 'data'), ('after', 'O'), ('opening', 'O'), ('the', 'O'), ('dropdown', 'O')]
#
#
# ['Enter " test1222 " in username input', ('enter', 'username', 'test1222')]
# [('enter', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['login " test1222 " in username input', ('login', 'username', 'test1222')]
# [('login', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['log in " test1222 " in username input', ('log in', 'username', 'test1222')]
# [('log', 'action'), ('in', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('username', 'label'), ('input', 'O')]
#
#
# ['enter " test1222 " in user name input', ('enter', 'user name', 'test1222')]
# [('enter', 'action'), ('"', 'O'), ('test1222', 'data'), ('"', 'O'), ('in', 'O'), ('user', 'label'), ('name', 'label'), ('input', 'O')]
#
#
# ['Enter the following information to login 1) username 2) password', ('enter', 'username', ''), ('enter', 'password', '')]
# [('enter', 'action'), ('the', 'O'), ('following', 'O'), ('information', 'O'), ('to', 'O'), ('login', 'O'), ('1)', 'O'), ('username', 'label'), ('2)', 'O'), ('password', 'label')]
#
#
# ['login the following information to login 1) username 2) password', ('login', 'username', ''), ('login', 'password', '')]
# [('login', 'action'), ('the', 'O'), ('following', 'O'), ('information', 'O'), ('to', 'O'), ('login', 'action'), ('1)', 'O'), ('username', 'label'), ('2)', 'O'), ('password', 'label')]
#
#
# ['log in the following information to login 1) username 2) password', ('log in', 'username', ''), ('log in', 'password', '')]
# [('log', 'action'), ('in', 'action'), ('the', 'O'), ('following', 'O'), ('information', 'O'), ('to', 'O'), ('login', 'O'), ('1)', 'O'), ('username', 'label'), ('2)', 'O'), ('password', 'label')]
#
#
# ['enter the following information to login 1) user name 2) password', ('enter', 'user name', ''), ('enter', 'password', '')]
# [('enter', 'action'), ('the', 'O'), ('following', 'O'), ('information', 'O'), ('to', 'O'), ('login', 'O'), ('1)', 'O'), ('user', 'label'), ('name', 'label'), ('2)', 'O'), ('password', 'label')]
#
#
# ['To create lead , enter username , lead name and address', ('enter', 'username', ''), ('enter', 'lead name', ''), ('enter', 'address', '')]
# [('to', 'O'), ('create', 'O'), ('lead', 'O'), (',', 'O'), ('enter', 'action'), ('username', 'label'), (',', 'O'), ('lead', 'label'), ('name', 'label'), ('and', 'O'), ('address', 'label')]
#
#
# ['to create lead , login username , lead name and address', ('login', 'username', ''), ('login', 'lead name', ''), ('login', 'address', '')]
# [('to', 'O'), ('create', 'O'), ('lead', 'O'), (',', 'O'), ('login', 'action'), ('username', 'label'), (',', 'O'), ('lead', 'label'), ('name', 'label'), ('and', 'O'), ('address', 'label')]
#
#
# ['to create lead , log in username , lead name and address', ('log in', 'username', ''), ('log in', 'lead name', ''), ('log in', 'address', '')]
# [('to', 'O'), ('create', 'O'), ('lead', 'O'), (',', 'O'), ('log', 'action'), ('in', 'action'), ('username', 'label'), (',', 'O'), ('lead', 'label'), ('name', 'label'), ('and', 'O'), ('address', 'label')]
#
#
# ['to create lead , enter user name , lead name and address', ('enter', 'user name', ''), ('enter', 'lead name', ''), ('enter', 'address', '')]
# [('to', 'O'), ('create', 'O'), ('lead', 'O'), (',', 'O'), ('enter', 'action'), ('user', 'label'), ('name', 'label'), (',', 'O'), ('lead', 'label'), ('name', 'label'), ('and', 'O'), ('address', 'label')]
#
#
# ['Enter " basket " in " field " data and enter " milk " in " search "', ('Enter', 'field', 'basket'), ('enter', 'search', 'milk')]
# [('enter', 'action'), ('"', 'O'), ('basket', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('field', 'label'), ('"', 'O'), ('data', 'O'), ('and', 'O'), ('enter', 'action'), ('"', 'O'), ('milk', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('search', 'label'), ('"', 'O')]
#
#
# ['login " basket " in " field " data and login " milk " in " search "', ('login', 'field', 'basket'), ('login', 'search', 'milk')]
# [('login', 'action'), ('"', 'O'), ('basket', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('field', 'label'), ('"', 'O'), ('data', 'O'), ('and', 'O'), ('login', 'action'), ('"', 'O'), ('milk', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('search', 'label'), ('"', 'O')]
#
#
# ['log in " basket " in " field " data and log in " milk " in " search "', ('log in', 'field', 'basket'), ('log in', 'search', 'milk')]
# [('log', 'action'), ('in', 'action'), ('"', 'O'), ('basket', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('field', 'label'), ('"', 'O'), ('data', 'O'), ('and', 'O'), ('log', 'O'), ('in', 'O'), ('"', 'O'), ('milk', 'data'), ('"', 'O'), ('in', 'O'), ('"', 'O'), ('search', 'label'), ('"', 'O')]
#
#
# ['Click on login button', ('click', 'login', '')]
# [('click', 'action'), ('on', 'O'), ('login', 'label'), ('button', 'O')]
#
#
# ['select on login button', ('select', 'login', '')]
# [('select', 'action'), ('on', 'O'), ('login', 'label'), ('button', 'O')]
#
#
# ['deselect on login button', ('deselect', 'login', '')]
# [('deselect', 'action'), ('on', 'O'), ('login', 'label'), ('button', 'O')]
#
#
# ['Save the lead by clicking on save', ('clicking', 'save', '')]
# [('save', 'label'), ('the', 'O'), ('lead', 'O'), ('by', 'O'), ('clicking', 'action'), ('on', 'O'), ('save', 'label')]
#
#
# ['save the lead by selecting on save', ('selecting', 'save', '')]
# [('save', 'label'), ('the', 'O'), ('lead', 'O'), ('by', 'O'), ('selecting', 'action'), ('on', 'O'), ('save', 'label')]

# %%
len(processed_data)
# Out:
# 434

# %%
def sanity(data_list):
    max_len = 0
    for token_list, tag_list in data_list:
        len1, len2 = len(token_list), len(tag_list)
        if len1 == len2:
            if max_len < len1: max_len = len1
        else:
            raise Exception
    
    return max_len
            
max_len = sanity(processed_data)

# %%
max_len
# Out:
# 102

# %%
headers = [x for x in range(max_len)]

# %%
path = r"C:\Users\anu10961\Work\POC\submission\autonomiq\data"

# %%
with open(os.path.join(path, 'tags.csv'), mode='w') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(headers)
    for item in processed_data:
        csv_writer.writerow(item[1])

# %%
with open(os.path.join(path, 'tokens.csv'), mode='w') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(headers)
    for item in processed_data:
        csv_writer.writerow(item[0])
